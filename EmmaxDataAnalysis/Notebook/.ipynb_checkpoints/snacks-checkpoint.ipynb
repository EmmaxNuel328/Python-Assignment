# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
value = pd.read_csv(r"\Users\DELL\Downloads\Kagglearchive\housing_price_dataset.csv")
value
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %% [markdown]
# 1. What is the average house price?

# %%
value.describe().T
# Out:
#               count           mean           std           min            25%  \
# SquareFeet  50000.0    2006.374680    575.513241   1000.000000    1513.000000
# Bedrooms    50000.0       3.498700      1.116326      2.000000       3.000000
# Bathrooms   50000.0       1.995420      0.815851      1.000000       1.000000
# YearBuilt   50000.0    1985.404420     20.719377   1950.000000    1967.000000
# Price       50000.0  224827.325151  76141.842966 -36588.165397  169955.860225
#
#                       50%            75%            max
# SquareFeet    2007.000000    2506.000000    2999.000000
# Bedrooms         3.000000       4.000000       5.000000
# Bathrooms        2.000000       3.000000       3.000000
# YearBuilt     1985.000000    2003.000000    2021.000000
# Price       225052.141166  279373.630052  492195.259972

# %% [markdown]
# Answer1 =  The average house price is 224827.325151

# %% [markdown]
# 2. What is the minimum and maximum price?
# Answer2 =  based on the dataset above the minimum price is -36588.165397 and the maximum price is 492195.259972

# %% [markdown]
# 3. How many houses are in the dataset?

# %% [markdown]
# 4. What is average square footage?
# Answer4 = based on the dataset above the average square footage is 2006.374680

# %%
value.count()
# Out:
# SquareFeet      50000
# Bedrooms        50000
# Bathrooms       50000
# Neighborhood    50000
# YearBuilt       50000
# Price           50000
# dtype: int64

# %% [markdown]
# answer3 = there are 50000 houses in the dataset

# %% [markdown]
# 5. What is the most common number of bedrooms?

# %%
 value['Bedrooms'].value_counts()
# Out:
# Bedrooms
# 3    12661
# 5    12468
# 2    12436
# 4    12435
# Name: count, dtype: int64

# %% [markdown]
#  Answer5 = the most common number of bedrooms is 3

# %% [markdown]
# 6. What is the most common number of bathrooms?

# %%
value['Bathrooms'].value_counts()
# Out:
# Bathrooms
# 1    16755
# 2    16719
# 3    16526
# Name: count, dtype: int64

# %% [markdown]
# Answer6 = the most common number of bathrooms is 1

# %% [markdown]
# 7. How many houses are in each neigborhood?

# %%
neighborhood = value.groupby('Neighborhood')
(neighborhood.describe().T).head()
# Out:
# Neighborhood             Rural        Suburb         Urban
# SquareFeet count  16676.000000  16721.000000  16603.000000
#            mean    2001.621132   2000.151127   2017.416913
#            std      577.115928    574.894261    574.398346
#            min     1000.000000   1000.000000   1000.000000
#            25%     1503.000000   1509.000000   1526.000000

# %% [markdown]
# Answer7 = rural is 16676.000000
#           suburb is 16721.000000
#           urban is 16603.000000

# %% [markdown]
# 8. What is the average price per neigbhorhood?
#    Answer8 = Based on the above dataset
#              rural is 224096.126040
#              suburb is 223234.189857
#              urban is 227166.197139

# %% [markdown]
# 9. What is the oldest house(year built)?

# %%
value['YearBuilt'].min()
# Out:
# np.int64(1950)

# %% [markdown]
# Answer9 = The oldest house was built in  1950

# %% [markdown]
# 10. What is the newest house?

# %%
value['YearBuilt'].max()
# Out:
# np.int64(2021)

# %% [markdown]
# Answer10 = The newest was built in 2021

# %% [markdown]
# 11. What is the average price with 3 bedrooms?

# %%
bedrooms_3 = value.query('Bedrooms == 3')
pd.DataFrame(bedrooms_3)
bedrooms_3.describe().T
# Out:
#               count           mean           std           min            25%  \
# SquareFeet  12661.0    2000.921886    577.690307   1000.000000    1503.000000
# Bedrooms    12661.0       3.000000      0.000000      3.000000       3.000000
# Bathrooms   12661.0       1.996051      0.818420      1.000000       1.000000
# YearBuilt   12661.0    1985.179212     20.708449   1950.000000    1967.000000
# Price       12661.0  221057.880496  75291.596928 -24183.000515  165914.808728
#
#                       50%            75%            max
# SquareFeet    1995.000000    2506.000000    2999.000000
# Bedrooms         3.000000       3.000000       3.000000
# Bathrooms        2.000000       3.000000       3.000000
# YearBuilt     1985.000000    2003.000000    2021.000000
# Price       220755.872358  274658.592497  468493.877841

# %% [markdown]
# Answer11 = The average is 221057.880496

# %% [markdown]
# 12. How many houses have more than 4 bedrooms?

# %%
bedrooms_greater_than_4 = value.query('Bedrooms > 4')
bedrooms_greater_than_4.describe().T
# Out:
#               count           mean           std           min            25%  \
# SquareFeet  12468.0    2003.298043    576.001060   1000.000000    1511.000000
# Bedrooms    12468.0       5.000000      0.000000      5.000000       5.000000
# Bathrooms   12468.0       2.000000      0.815645      1.000000       1.000000
# YearBuilt   12468.0    1985.625441     20.793188   1950.000000    1968.000000
# Price       12468.0  232595.478259  76416.776442 -36588.165397  177639.465749
#
#                       50%            75%            max
# SquareFeet    2001.000000    2499.000000    2999.000000
# Bedrooms         5.000000       5.000000       5.000000
# Bathrooms        2.000000       3.000000       3.000000
# YearBuilt     1986.000000    2004.000000    2021.000000
# Price       232098.123456  288776.782705  492195.259972

# %% [markdown]
# Answer12 = There are 12468 houses with more than 4 bedrooms

# %% [markdown]
# 13. What is the average square footage of urban houses?
# Answer13 = The average square footage of urban houses is 2017.416913

# %% [markdown]
# 14. What is the median price?
# Answer14 = The median price is 225052.141166

# %% [markdown]
# 15. What is the price distribution?

# %%
prices = value['Price']
prices.hist()
# Out:
# <Axes: >

# %% [markdown]
# 16. What percentage of houses are in the suburb areas?

# %%
value.count()
# Out:
# SquareFeet      50000
# Bedrooms        50000
# Bathrooms       50000
# Neighborhood    50000
# YearBuilt       50000
# Price           50000
# dtype: int64

# %%
neighborhoods = value.groupby('Neighborhood')
neighborhoods_houses = neighborhoods.describe().T
number_of_suburb = neighborhoods_houses['Suburb'].count()
number_of_suburb
# total_number_of_houses = value.count()
# total_number_of_houses
# Out:
# np.int64(40)

# %%
percentage = (number_of_suburb/total_number_of_houses)*100
percentage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 percentage = (number_of_suburb/total_number_of_houses)*100
#       2 percentage
#
# NameError: name 'total_number_of_houses' is not defined
